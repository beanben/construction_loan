# %%
# Adds the parent directory to the path to find the construction_loan package
import sys
sys.path.append('..')

from construction_loan.budget import Budget
from construction_loan.cashflow import Cashflow
from construction_loan.visualiser import DataVisualiser

# %pdb on

visualiser = DataVisualiser()
# Out:
# Automatic pdb calling has been turned ON

# %%
# prepare the dataframe
csv_file = '/Users/benoitfesquet/Dev/construction_loan/data/jensco_budget.csv'
budget_instance = Budget.from_csv(csv_file)
budget_df = budget_instance.df
visualiser.display_dataframe(budget_df)
# Out:
# Execution of from_csv took 0.012742042541503906 seconds
#               cost_category                                   cost_type  \
# 0         Acquisition costs                            Site acquisition
# 1   Other acquisition costs     Stamp Duty inc VAT (on actual purchase)
# 2   Other acquisition costs              Jensco legal costs land & S106
# 3   Other acquisition costs  Jensco legal costs funding (inc Oak North)
# 4   Other acquisition costs        Jensco legal costs - Kinetic funding
# 5   Other acquisition costs            Jensco legal fees - construction
# 6   Other acquisition costs                         Bank Valuation Fees
# 7   Other acquisition costs                Vat recovered on day 1 costs
# 8        Construction costs                          Construction costs
# 9         Professional fees                  Development Management Fee
# 10        Professional fees                       Project managers & QS
# 11        Professional fees                M&E Consultant - client side
# 12        Professional fees               Planning costs - see schedule
# 13        Professional fees          Architect / Planning / Survey Fees
# 14        Professional fees                        Bank Fee Contingency
# 15        Professional fees                    Material Storage Charges
# 16        Professional fees                 Legal Fees and Accountancy
# 17        Professional fees                 Unallocated fee contingency
# 18          Statutory costs      S106 / 278 (over build cost inclusion)
# 19                Marketing           1st year mobilisation & marketing
# 20              Other costs                 Insurances - Developer Risk
# 21              Other costs                  Knight Frank (debt broker)
# 22      Project contingency             Irrecoverable VAT (contingency)
# 23      Project contingency                Risk Allowance (contingency)
#
#         supplier     amount  start_date    end_date
# 0            NaN  7,740,000  2020-12-09  2020-12-09
# 1            NaN    189,500  2020-12-09  2020-12-09
# 2            NaN     23,563  2020-12-09  2020-12-09
# 3            NaN     39,350  2020-12-09  2020-12-09
# 4            NaN     33,150  2020-12-09  2020-12-09
# 5            NaN     38,400  2020-12-09  2020-12-09
# 6            NaN     16,200  2020-12-09  2020-12-09
# 7            NaN    -20,941  2021-02-03  2021-02-03
# 8            NaN 29,271,426  2021-02-03  2022-09-30
# 9            NaN    338,000  2022-09-30  2022-09-30
# 10           NaN    221,877  2021-02-24  2022-09-30
# 11           NaN     88,300  2021-02-24  2022-09-30
# 12           NaN    425,070  2020-12-09  2020-12-09
# 13           NaN     47,810  2021-02-03  2021-11-24
# 14           NaN      2,000  2021-07-23  2022-09-30
# 15           NaN      7,000  2021-09-17  2022-09-30
# 16           NaN     26,676  2021-11-24  2021-11-24
# 17           NaN     31,303  2022-01-20  2022-01-20
# 18           NaN    390,000  2021-02-03  2022-09-30
# 19           NaN    250,000  2021-05-20  2022-09-30
# 20           NaN     72,374  2020-12-09  2020-12-09
# 21  Knight Frank    300,000  2020-12-09  2020-12-09
# 22           NaN    100,000  2022-09-30  2022-09-30
# 23           NaN    983,660  2021-12-22  2022-09-30

# %%
budget_summary_df = budget_instance.total_cost_by_level('cost_category')
visualiser.display_dataframe(budget_summary_df)

# %%
cashflow_instance = Cashflow.from_budget(budget_instance)
cashflow_df = cashflow_instance.df
cashflow_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cashflow_instance = Cashflow.from_budget(budget_instance)
#       2 cashflow_df = cashflow_instance.df
#       3 cashflow_df
#
# File ~/Dev/construction_loan/notebooks/../construction_loan/utils.py:10, in time_execution.<locals>.wrapper(*args, **kwargs)
#       7 @functools.wraps(func)
#       8 def wrapper(*args, **kwargs):
#       9     start_time = time.time()
# ---> 10     result = func(*args, **kwargs)
#      11     end_time = time.time()
#      12     print(f"Execution of {func.__name__} took {end_time - start_time} seconds")
#
# File ~/Dev/construction_loan/notebooks/../construction_loan/cashflow.py:48, in Cashflow.from_budget(cls, budget_instance)
#      44     daily_costs.iloc[-1] += row['amount'] - daily_costs.sum()
#      45     cashflow_df.loc[daily_costs.index, (row['cost_category'], row['cost_type'], row['supplier'])] += daily_costs.values
# ---> 48 cashflow_df = cls.costs_grouped_by_billing_period(cashflow_df)
#      50 return cls(cashflow_df)
#
# TypeError: Cashflow.costs_grouped_by_billing_period() missing 1 required positional argument: 'df'
# > /Users/benoitfesquet/Dev/construction_loan/construction_loan/cashflow.py(48)from_budget()
#      46
#      47
# ---> 48         cashflow_df = cls.costs_grouped_by_billing_period(cashflow_df)
#      49
#      50         return cls(cashflow_df)

# %%
cashflow_instance.costs_grouped_by_level('cost_category')
